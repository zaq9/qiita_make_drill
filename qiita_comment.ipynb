# %% [markdown]
# <a href="https://colab.research.google.com/github/zaq9/qiita_make_drill/blob/master/qiita_comment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""計算練習ドリルを作成（新規ブック作成版）
"""

import random
import openpyxl

wb = openpyxl.Workbook()  #新規ワークブックを作成
sheet = wb.active
list_ = [[a, b] for a in range(1, 10) for b in range(1, 10)]
random.shuffle(list_)

for n, v in enumerate(list_):
	x, y = n // 6, n % 6    # 座標変換1 (碁盤タイプ） 
	r, c = x+3 , y*6+1      # 座標変換２【(r,c】各計算式左上座標）
	sheet.cell(row=r, column=c, value=v[0])
	sheet.cell(row=r, column=c + 1, value='+')
	sheet.cell(row=r, column=c + 2, value=v[1])
	sheet.cell(row=r, column=c + 3, value='=')
	print(n,(x,y),(r,c),v)  #参考に座標変換内容表示
	
wb.save('output.xlsx')
# Out:
# (0, (0, 0), (3, 1), [7, 8])
# (1, (0, 1), (3, 7), [1, 8])
# (2, (0, 2), (3, 13), [6, 9])
# (3, (0, 3), (3, 19), [9, 7])
# (4, (0, 4), (3, 25), [2, 1])
# (5, (0, 5), (3, 31), [3, 1])
# (6, (1, 0), (4, 1), [9, 3])
# (7, (1, 1), (4, 7), [2, 5])
# (8, (1, 2), (4, 13), [5, 2])
# (9, (1, 3), (4, 19), [7, 4])
# (10, (1, 4), (4, 25), [4, 2])
# (11, (1, 5), (4, 31), [6, 6])
# (12, (2, 0), (5, 1), [7, 9])
# (13, (2, 1), (5, 7), [4, 8])
# (14, (2, 2), (5, 13), [8, 5])
# (15, (2, 3), (5, 19), [8, 3])
# (16, (2, 4), (5, 25), [4, 5])
# (17, (2, 5), (5, 31), [1, 9])
# (18, (3, 0), (6, 1), [3, 5])
# (19, (3, 1), (6, 7), [6, 8])
# (20, (3, 2), (6, 13), [1, 3])
# (21, (3, 3), (6, 19), [4, 3])
# (22, (3, 4), (6, 25), [2, 9])
# (23, (3, 5), (6, 31), [3, 9])
# (24, (4, 0), (7, 1), [4, 7])
# (25, (4, 1), (7, 7), [2, 7])
# (26, (4, 2), (7, 13), [2, 4])
# (27, (4, 3), (7, 19), [9, 2])
# (28, (4, 4), (7, 25), [1, 4])
# (29, (4, 5), (7, 31), [4, 9])
# (30, (5, 0), (8, 1), [7, 7])
# (31, (5, 1), (8, 7), [3, 8])
# (32, (5, 2), (8, 13), [2, 8])
# (33, (5, 3), (8, 19), [8, 4])
# (34, (5, 4), (8, 25), [7, 5])
# (35, (5, 5), (8, 31), [2, 6])
# (36, (6, 0), (9, 1), [1, 6])
# (37, (6, 1), (9, 7), [9, 1])
# (38, (6, 2), (9, 13), [3, 4])
# (39, (6, 3), (9, 19), [8, 6])
# (40, (6, 4), (9, 25), [6, 2])
# (41, (6, 5), (9, 31), [5, 7])
# (42, (7, 0), (10, 1), [4, 1])
# (43, (7, 1), (10, 7), [8, 8])
# (44, (7, 2), (10, 13), [5, 1])
# (45, (7, 3), (10, 19), [1, 7])
# (46, (7, 4), (10, 25), [1, 2])
# (47, (7, 5), (10, 31), [7, 6])
# (48, (8, 0), (11, 1), [2, 2])
# (49, (8, 1), (11, 7), [9, 8])
# (50, (8, 2), (11, 13), [3, 7])
# (51, (8, 3), (11, 19), [5, 4])
# (52, (8, 4), (11, 25), [5, 3])
# (53, (8, 5), (11, 31), [8, 2])
# (54, (9, 0), (12, 1), [9, 9])
# (55, (9, 1), (12, 7), [8, 1])
# (56, (9, 2), (12, 13), [8, 7])
# (57, (9, 3), (12, 19), [8, 9])
# (58, (9, 4), (12, 25), [1, 1])
# (59, (9, 5), (12, 31), [5, 6])
# (60, (10, 0), (13, 1), [3, 3])
# (61, (10, 1), (13, 7), [7, 3])
# (62, (10, 2), (13, 13), [5, 9])
# (63, (10, 3), (13, 19), [9, 4])
# (64, (10, 4), (13, 25), [9, 5])
# (65, (10, 5), (13, 31), [7, 1])
# (66, (11, 0), (14, 1), [1, 5])
# (67, (11, 1), (14, 7), [7, 2])
# (68, (11, 2), (14, 13), [6, 1])
# (69, (11, 3), (14, 19), [6, 3])
# (70, (11, 4), (14, 25), [3, 6])
# (71, (11, 5), (14, 31), [4, 4])
# (72, (12, 0), (15, 1), [9, 6])
# (73, (12, 1), (15, 7), [4, 6])
# (74, (12, 2), (15, 13), [6, 4])
# (75, (12, 3), (15, 19), [2, 3])
# (76, (12, 4), (15, 25), [5, 5])
# (77, (12, 5), (15, 31), [6, 5])
# (78, (13, 0), (16, 1), [5, 8])
# (79, (13, 1), (16, 7), [3, 2])
# (80, (13, 2), (16, 13), [6, 7])
